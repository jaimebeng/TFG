# %% [markdown]
# This notebook performs an initial exploration of stock price data for **30 companies** (2010–2026).
#
# Historical data was downloaded and data integrity was validated by checking:
#
# - absence of null values
# - correct data types
# - ordered dates
# - detection of temporal gaps
# - absence of negative values
#
# Finally, the temporal range of existence for each asset was analyzed to establish a **dynamic universe of stocks**.

# %%
# imports
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

sys.path.append(os.path.abspath(".."))
from src.data.download_data import DownloadData

import pandas_market_calendars as mcal

# %%
# read data
tickers = [
    # Technology
    "AAPL", "MSFT", "NVDA", "GOOG", "META", "AVGO",

    # Consumer Discretionary
    "AMZN", "HD", "MCD", "NKE",

    # Health
    "JNJ", "UNH", "PFE", "ABBV",

    # Industrials
    "CAT", "BA", "UPS", "MMM",

    # Energy
    "XOM", "CVX", "SLB",

    # Financials
    "JPM", "BAC", "GS", "MS",

    # Utilities / Materials
    "NEE", "LIN", "DOW",

    # Telecom / Communications
    "VZ", "CMCSA"
]



dfs = {
    tick:pd.read_csv(os.path.join("/home/jaime/Documents/TFG/data/raw/",csv), header=[0,1], index_col=0)
    for tick,csv in zip(sorted(tickers),sorted(os.listdir("/home/jaime/Documents/TFG/data/raw/")))
    if csv != "GSPC.csv"}

# %%
# view data

df = dfs["AAPL"]

df.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.412383  6.427064  6.363543  6.395004  493729600
# 2010-01-05  6.423470  6.459726  6.389612  6.430063  601904800
# 2010-01-06  6.321295  6.448937  6.314703  6.423469  552160000
# 2010-01-07  6.309610  6.352158  6.263767  6.344667  477131200
# 2010-01-08  6.351560  6.352160  6.264069  6.301222  447610800

# %%
# need to drop the Ticker row and clean the df for better visualization
df = df.droplevel(1,axis=1)
df.columns.name = None
df.head()
# Out:
#                Close      High       Low      Open     Volume
# Date
# 2010-01-04  6.412383  6.427064  6.363543  6.395004  493729600
# 2010-01-05  6.423470  6.459726  6.389612  6.430063  601904800
# 2010-01-06  6.321295  6.448937  6.314703  6.423469  552160000
# 2010-01-07  6.309610  6.352158  6.263767  6.344667  477131200
# 2010-01-08  6.351560  6.352160  6.264069  6.301222  447610800

# %%
# make data a datetime not a string

df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2026-01-16', '2026-01-20', '2026-01-21', '2026-01-22',
#                '2026-01-23', '2026-01-26', '2026-01-27', '2026-01-28',
#                '2026-01-29', '2026-01-30'],
#               dtype='datetime64[us]', name='Date', length=4044, freq=None)

# %%
# check for null values
df.isna().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
# check if there are any missing data gaps in any of the 30 assets
for ticker,df in dfs.items():
    print(f"{ticker}: {df.isna().sum().sum() == 0}")
# Out:
# AAPL: True
# ABBV: True
# AMZN: True
# AVGO: True
# BA: True
# BAC: True
# CAT: True
# CMCSA: True
# CVX: True
# DOW: True
# GOOG: True
# GS: True
# JNJ: True
# JPM: True
# LIN: True
# MCD: True
# META: True
# MMM: True
# MS: True
# MSFT: True
# NEE: True
# NKE: True
# NVDA: True
# PFE: True
# SLB: True
# UNH: True
# UPS: True
# VZ: True
# XOM: True

# %%
# data is complete
# check that the data type for all dfs is correct

expected_types = {
    'Open': 'float64',
    'High': 'float64',
    'Low': 'float64',
    'Close': 'float64',
    'Volume': 'int64'
}

for ticker,df in dfs.items():
    df = df.droplevel(1,axis=1)
    df.columns.name = None
    for col, expected in expected_types.items():
        if df[col].dtype != expected:
                print(f"{ticker}: {col} incorrect dtype: {df[col].dtype} (expected: {expected})")

# %%
# data type is correct
# check if dates are ordered in chronological order


for ticker,df in dfs.items():
    is_sorted = df.index.is_monotonic_increasing
    print(f"{ticker}: Ordered dates: {is_sorted}")
# Out:
# AAPL: Ordered dates: True
# ABBV: Ordered dates: True
# AMZN: Ordered dates: True
# AVGO: Ordered dates: True
# BA: Ordered dates: True
# BAC: Ordered dates: True
# CAT: Ordered dates: True
# CMCSA: Ordered dates: True
# CVX: Ordered dates: True
# DOW: Ordered dates: True
# GOOG: Ordered dates: True
# GS: Ordered dates: True
# JNJ: Ordered dates: True
# JPM: Ordered dates: True
# LIN: Ordered dates: True
# MCD: Ordered dates: True
# META: Ordered dates: True
# MMM: Ordered dates: True
# MS: Ordered dates: True
# MSFT: Ordered dates: True
# NEE: Ordered dates: True
# NKE: Ordered dates: True
# NVDA: Ordered dates: True
# PFE: Ordered dates: True
# SLB: Ordered dates: True
# UNH: Ordered dates: True
# UPS: Ordered dates: True
# VZ: Ordered dates: True
# XOM: Ordered dates: True

# %%
# dates are ordered
# are there temporal gaps?

start = "2010-01-01"
end = "2026-02-01"


nyse = mcal.get_calendar('NYSE')
schedule = nyse.schedule(start_date=start, end_date=end)
expected_days = mcal.date_range(schedule, frequency='1D')
expected_days = expected_days.normalize().tz_localize(None)

for ticker,df in dfs.items():
    df.index = pd.to_datetime(df.index, utc=True)
    df_days = df.index.normalize().tz_localize(None)
    missing_days = expected_days.difference(df_days)
    extra_days = df_days.difference(expected_days)
    duplicates = df.index[df.index.duplicated()]
    print(f"{ticker}: Missing days: ", missing_days)
    print(f"{ticker}: Extra days: ", extra_days)
    print(f"{ticker}: Duplicates: ",duplicates)
# Out:
# AAPL: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AAPL: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AAPL: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# ABBV: Missing days:  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2012-12-17', '2012-12-18', '2012-12-19', '2012-12-20',
#                '2012-12-21', '2012-12-24', '2012-12-26', '2012-12-27',
#                '2012-12-28', '2012-12-31'],
#               dtype='datetime64[us]', length=754, freq=None)
# ABBV: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# ABBV: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# AMZN: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AMZN: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AMZN: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# AVGO: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AVGO: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# AVGO: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# BA: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# BA: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# BA: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# BAC: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# BAC: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# BAC: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# CAT: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CAT: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CAT: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# CMCSA: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CMCSA: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CMCSA: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# CVX: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CVX: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# CVX: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# DOW: Missing days:  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2019-03-06', '2019-03-07', '2019-03-08', '2019-03-11',
#                '2019-03-12', '2019-03-13', '2019-03-14', '2019-03-15',
#                '2019-03-18', '2019-03-19'],
#               dtype='datetime64[us]', length=2317, freq=None)
# DOW: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# DOW: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# GOOG: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GOOG: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GOOG: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# GS: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GS: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GS: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# JNJ: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# JNJ: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# JNJ: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# JPM: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# JPM: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# JPM: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# LIN: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# LIN: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# LIN: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# MCD: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MCD: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MCD: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# META: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# META: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# META: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# MMM: Missing days:  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2012-05-04', '2012-05-07', '2012-05-08', '2012-05-09',
#                '2012-05-10', '2012-05-11', '2012-05-14', '2012-05-15',
#                '2012-05-16', '2012-05-17'],
#               dtype='datetime64[us]', length=599, freq=None)
# MMM: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MMM: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# MS: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MS: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MS: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# MSFT: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MSFT: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# MSFT: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# NEE: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NEE: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NEE: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# NKE: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NKE: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NKE: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# NVDA: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NVDA: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# NVDA: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# PFE: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# PFE: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# PFE: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# SLB: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# SLB: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# SLB: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# UNH: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# UNH: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# UNH: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# UPS: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# UPS: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# UPS: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# VZ: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# VZ: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# VZ: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)
# XOM: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# XOM: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# XOM: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)

# %%
# there are no temporal gaps, for assets incorporated late we use a dynamic universe of stocks

# check if there are any negative values in the dfs


for ticker,df in dfs.items():
    print(f"{ticker}: ", (df < 0).any())
# Out:
# AAPL:  Price      Ticker
# Adj Close  AAPL      False
# Close      AAPL      False
# High       AAPL      False
# Low        AAPL      False
# Open       AAPL      False
# Volume     AAPL      False
# dtype: bool
# ABBV:  Price      Ticker
# Adj Close  ABBV      False
# Close      ABBV      False
# High       ABBV      False
# Low        ABBV      False
# Open       ABBV      False
# Volume     ABBV      False
# dtype: bool
# AMZN:  Price      Ticker
# Adj Close  AMZN      False
# Close      AMZN      False
# High       AMZN      False
# Low        AMZN      False
# Open       AMZN      False
# Volume     AMZN      False
# dtype: bool
# AVGO:  Price      Ticker
# Adj Close  AVGO      False
# Close      AVGO      False
# High       AVGO      False
# Low        AVGO      False
# Open       AVGO      False
# Volume     AVGO      False
# dtype: bool
# BA:  Price      Ticker
# Adj Close  BA        False
# Close      BA        False
# High       BA        False
# Low        BA        False
# Open       BA        False
# Volume     BA        False
# dtype: bool
# BAC:  Price      Ticker
# Adj Close  BAC       False
# Close      BAC       False
# High       BAC       False
# Low        BAC       False
# Open       BAC       False
# Volume     BAC       False
# dtype: bool
# CAT:  Price      Ticker
# Adj Close  CAT       False
# Close      CAT       False
# High       CAT       False
# Low        CAT       False
# Open       CAT       False
# Volume     CAT       False
# dtype: bool
# CMCSA:  Price      Ticker
# Adj Close  CMCSA     False
# Close      CMCSA     False
# High       CMCSA     False
# Low        CMCSA     False
# Open       CMCSA     False
# Volume     CMCSA     False
# dtype: bool
# CVX:  Price      Ticker
# Adj Close  CVX       False
# Close      CVX       False
# High       CVX       False
# Low        CVX       False
# Open       CVX       False
# Volume     CVX       False
# dtype: bool
# DOW:  Price      Ticker
# Adj Close  DOW       False
# Close      DOW       False
# High       DOW       False
# Low        DOW       False
# Open       DOW       False
# Volume     DOW       False
# dtype: bool
# GOOG:  Price      Ticker
# Adj Close  GOOG      False
# Close      GOOG      False
# High       GOOG      False
# Low        GOOG      False
# Open       GOOG      False
# Volume     GOOG      False
# dtype: bool
# GS:  Price      Ticker
# Adj Close  GS        False
# Close      GS        False
# High       GS        False
# Low        GS        False
# Open       GS        False
# Volume     GS        False
# dtype: bool
# JNJ:  Price      Ticker
# Adj Close  HD        False
# Close      HD        False
# High       HD        False
# Low        HD        False
# Open       HD        False
# Volume     HD        False
# dtype: bool
# JPM:  Price      Ticker
# Adj Close  JNJ       False
# Close      JNJ       False
# High       JNJ       False
# Low        JNJ       False
# Open       JNJ       False
# Volume     JNJ       False
# dtype: bool
# LIN:  Price      Ticker
# Adj Close  JPM       False
# Close      JPM       False
# High       JPM       False
# Low        JPM       False
# Open       JPM       False
# Volume     JPM       False
# dtype: bool
# MCD:  Price      Ticker
# Adj Close  LIN       False
# Close      LIN       False
# High       LIN       False
# Low        LIN       False
# Open       LIN       False
# Volume     LIN       False
# dtype: bool
# META:  Price      Ticker
# Adj Close  MCD       False
# Close      MCD       False
# High       MCD       False
# Low        MCD       False
# Open       MCD       False
# Volume     MCD       False
# dtype: bool
# MMM:  Price      Ticker
# Adj Close  META      False
# Close      META      False
# High       META      False
# Low        META      False
# Open       META      False
# Volume     META      False
# dtype: bool
# MS:  Price      Ticker
# Adj Close  MMM       False
# Close      MMM       False
# High       MMM       False
# Low        MMM       False
# Open       MMM       False
# Volume     MMM       False
# dtype: bool
# MSFT:  Price      Ticker
# Adj Close  MS        False
# Close      MS        False
# High       MS        False
# Low        MS        False
# Open       MS        False
# Volume     MS        False
# dtype: bool
# NEE:  Price      Ticker
# Adj Close  MSFT      False
# Close      MSFT      False
# High       MSFT      False
# Low        MSFT      False
# Open       MSFT      False
# Volume     MSFT      False
# dtype: bool
# NKE:  Price      Ticker
# Adj Close  NEE       False
# Close      NEE       False
# High       NEE       False
# Low        NEE       False
# Open       NEE       False
# Volume     NEE       False
# dtype: bool
# NVDA:  Price      Ticker
# Adj Close  NKE       False
# Close      NKE       False
# High       NKE       False
# Low        NKE       False
# Open       NKE       False
# Volume     NKE       False
# dtype: bool
# PFE:  Price      Ticker
# Adj Close  NVDA      False
# Close      NVDA      False
# High       NVDA      False
# Low        NVDA      False
# Open       NVDA      False
# Volume     NVDA      False
# dtype: bool
# SLB:  Price      Ticker
# Adj Close  PFE       False
# Close      PFE       False
# High       PFE       False
# Low        PFE       False
# Open       PFE       False
# Volume     PFE       False
# dtype: bool
# UNH:  Price      Ticker
# Adj Close  SLB       False
# Close      SLB       False
# High       SLB       False
# Low        SLB       False
# Open       SLB       False
# Volume     SLB       False
# dtype: bool
# UPS:  Price      Ticker
# Adj Close  UNH       False
# Close      UNH       False
# High       UNH       False
# Low        UNH       False
# Open       UNH       False
# Volume     UNH       False
# dtype: bool
# VZ:  Price      Ticker
# Adj Close  UPS       False
# Close      UPS       False
# High       UPS       False
# Low        UPS       False
# Open       UPS       False
# Volume     UPS       False
# dtype: bool
# XOM:  Price      Ticker
# Adj Close  VZ        False
# Close      VZ        False
# High       VZ        False
# Low        VZ        False
# Open       VZ        False
# Volume     VZ        False
# dtype: bool

# %%
# there are no negative values
# let's look at basic statistics of some assets

# calculate for each asset its temporal existence range
for ticker,df in dfs.items():
    df.index = df.index.normalize().tz_localize(None)
    start = df.index[0]
    end = df.index[len(df.index)-1]
    print(f"{ticker}: {start} - {end}")
# Out:
# AAPL: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# ABBV: 2013-01-02 00:00:00 - 2026-01-30 00:00:00
# AMZN: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# AVGO: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# BA: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# BAC: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# CAT: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# CMCSA: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# CVX: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# DOW: 2019-03-20 00:00:00 - 2026-01-30 00:00:00
# GOOG: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# GS: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# JNJ: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# JPM: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# LIN: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# MCD: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# META: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# MMM: 2012-05-18 00:00:00 - 2026-01-30 00:00:00
# MS: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# MSFT: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# NEE: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# NKE: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# NVDA: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# PFE: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# SLB: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# UNH: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# UPS: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# VZ: 2010-01-04 00:00:00 - 2026-01-30 00:00:00
# XOM: 2010-01-04 00:00:00 - 2026-01-30 00:00:00

# %%
# check which assets are incorporated late and at what date

start_actual = pd.Timestamp('2010-01-04 00:00:00')

for ticker,df in dfs.items():
    df.index = df.index.normalize().tz_localize(None)
    start = df.index[0]
    if start != start_actual:
        print(f"{ticker}: {start}")
# Out:
# ABBV: 2013-01-02 00:00:00
# DOW: 2019-03-20 00:00:00
# MMM: 2012-05-18 00:00:00

# %%
# calculate mean, median, minimum and maximum, etc

for ticker, df in dfs.items():
    print("\n" + "="*60)
    print(f"Estadísticas para {ticker}")
    print("="*60)
    print(df.describe().round(3))
# Out:
# ============================================================
# Estadísticas para AAPL
# ============================================================
# Price      Close      High       Low      Open        Volume
# Ticker      AAPL      AAPL      AAPL      AAPL          AAPL
# count   4044.000  4044.000  4044.000  4044.000  4.044000e+03
# mean      78.328    79.104    77.482    78.267  2.181747e+08
# std       75.835    76.572    75.024    75.763  2.152739e+08
# min        5.754     5.873     5.700     5.764  1.791060e+07
# 25%       18.275    18.468    18.088    18.335  7.703408e+07
# 50%       39.250    39.758    38.769    39.192  1.302068e+08
# 75%      143.472   145.099   142.182   143.277  2.889565e+08
# max      285.922   288.350   283.035   285.932  1.880998e+09
#
# ============================================================
# Estadísticas para ABBV
# ============================================================
# Price      Close      High       Low      Open        Volume
# Ticker      ABBV      ABBV      ABBV      ABBV          ABBV
# count   3290.000  3290.000  3290.000  3290.000  3.290000e+03
# mean      87.059    87.918    86.112    87.016  7.301912e+06
# std       54.467    54.963    53.894    54.430  4.871245e+06
# min       19.899    20.041    19.675    19.840  1.378600e+06
# 25%       41.879    42.297    41.483    41.881  4.734600e+06
# 50%       67.976    68.913    67.297    68.143  6.180250e+06
# 75%      130.513   131.640   128.896   130.380  8.486275e+06
# max      240.694   241.118   230.983   237.257  1.227402e+08
#
# ============================================================
# Estadísticas para AMZN
# ============================================================
# Price      Close      High       Low      Open        Volume
# Ticker      AMZN      AMZN      AMZN      AMZN          AMZN
# count   4044.000  4044.000  4044.000  4044.000  4.044000e+03
# mean
# count   4044.000  4044.000  4044.000  4044.000  4.044000e+03
# mean      89.044    89.829    88.234    89.034  3.783571e+06
# std       39.086    39.523    38.627    39.078  2.270855e+06
# min       32.607    32.764    32.385    32.671  8.359000e+05
# 25%       63.057    63.466    62.625    62.992  2.493600e+06
# 50%       78.968    79.770    78.249    79.038  3.232450e+06
# 75%      122.010   123.160   120.748   122.134  4.359550e+06
# max      190.229   191.548   186.229   189.032  4.117040e+07
#
# ============================================================
# Estadísticas para XOM
# ============================================================
# Price      Close      High       Low      Open        Volume
# Ticker        VZ        VZ        VZ        VZ            VZ
# count   4044.000  4044.000  4044.000  4044.000  4.044000e+03
# mean      30.858    31.088    30.615    30.857  1.765127e+07
# std        8.594     8.665     8.527     8.593  1.295524e+07
# min       11.267    11.451    11.083    11.334  3.375400e+06
# 25%       26.055    26.252    25.831    26.110  1.208585e+07
# 50%       30.895    31.142    30.668    30.907  1.540990e+07
# 75%       39.091    39.413    38.739    39.058  2.041838e+07
# max       44.977    45.130    44.634    44.838  6.166205e+08

# %%
# plots of closing prices for assets

tickers = list(dfs.keys())
n = len(tickers)

rows = 3
cols = 10

fig, axes = plt.subplots(rows, cols, figsize=(30, 10), sharex=False, sharey=False)
axes = axes.flatten()

for i, ticker in enumerate(tickers):
    ax = axes[i]
    df = dfs[ticker]
    ax.plot(df['Close'], linewidth=1)
    ax.set_title(ticker, fontsize=10)
    ax.grid(True)

for j in range(i+1, rows*cols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

for ticker, df in dfs.items():
    plt.plot(df['Close'], label=ticker)

plt.title('Closing Prices — Asset Comparison')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
# now we do the same for the S&P500

df = pd.read_csv("/home/jaime/Documents/TFG/data/raw/GSPC.csv", header=[0,1], index_col=0)

# %%
df.head()
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2010-01-04  1132.989990  1133.869995  1116.560059  1116.560059  3991400000
# 2010-01-05  1136.520020  1136.630005  1129.660034  1132.660034  2491020000
# 2010-01-06  1137.140015  1139.189941  1133.949951  1135.709961  4972660000
# 2010-01-07  1141.689941  1142.459961  1131.319946  1136.270020  5270680000
# 2010-01-08  1144.979980  1145.390015  1136.219971  1140.520020  4389590000

# %%
df.isna().sum()
# Out:
# Price   Ticker
# Close   ^GSPC     0
# High    ^GSPC     0
# Low     ^GSPC     0
# Open    ^GSPC     0
# Volume  ^GSPC     0
# dtype: int64

# %%
expected_types = {
    'Open': 'float64',
    'High': 'float64',
    'Low': 'float64',
    'Close': 'float64',
    'Volume': 'int64'
}


df.columns.name = None
for col, expected in expected_types.items():
    if df[col].dtype != expected:
            print(f"{col} incorrect dtype: {df[col].dtype} (expected: {expected})")

# %%
start = "2010-01-01"
end = "2026-02-01"


nyse = mcal.get_calendar('NYSE')
schedule = nyse.schedule(start_date=start, end_date=end)
expected_days = mcal.date_range(schedule, frequency='1D')
expected_days = expected_days.normalize().tz_localize(None)

df.index = pd.to_datetime(df.index, utc=True)
df_days = df.index.normalize().tz_localize(None)
missing_days = expected_days.difference(df_days)
extra_days = df_days.difference(expected_days)
duplicates = df.index[df.index.duplicated()]
print(f"GSPC: Missing days: ", missing_days)
print(f"GSPC: Extra days: ", extra_days)
print(f"GSPC: Duplicates: ",duplicates)
# Out:
# GSPC: Missing days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GSPC: Extra days:  DatetimeIndex([], dtype='datetime64[us]', freq=None)
# GSPC: Duplicates:  DatetimeIndex([], dtype='datetime64[us, UTC]', name='Date', freq=None)

# %%
(df < 0).any()
# Out:
# Close     False
# High      False
# Low       False
# Open      False
# Volume    False
# dtype: bool

# %%
df.describe().round(3)
# Out:
#           Close      High       Low      Open        Volume
# count  4044.000  4044.000  4044.000  4044.000  4.044000e+03
# mean   2964.715  2979.817  2947.215  2964.116  4.019324e+09
# std    1513.422  1520.658  1505.249  1513.304  9.972772e+08
# min    1022.580  1032.950  1010.910  1027.650  0.000000e+00
# 25%    1814.430  1823.698  1805.652  1810.043  3.400402e+09
# 50%    2596.860  2617.525  2577.510  2589.960  3.837220e+09
# 75%    4105.900  4130.658  4073.980  4096.200  4.455315e+09
# max    6978.600  7002.280  6963.460  7002.000  1.061781e+10

# %%
plt.figure(figsize=(8,3))


plt.plot(df['Close'], label="GSPC")

plt.title('Closing Prices — S&P500')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Complete Summary of Data Discoveries
#
# ### Data Integrity
#
# - No null data: the 30 assets do not present missing values.
# - Correct data types: *Open, High, Low, Close, Adj Close* (`float64`) and *Volume* (`int64`).
# - Chronologically ordered dates: all assets are ordered temporally.
# - No temporal gaps: they match the NYSE trading calendar.
# - No duplicates or negative values.
#
# ### Assets Incorporated Late
#
# - **META**: since *2012-05-18* (IPO).
# - **ABBV**: since *2013-01-02*.
# - **DOW**: since *2019-03-20*.
#
# ### Descriptive Statistics Analysis
#
# The statistics of the 30 assets show **strong heterogeneity**:
#
# - **High growth**: NVDA, MSFT, GOOG, META and AAPL present high average prices and very high maximums, reflecting clearly bullish trends since 2010.
# - **Moderate growth**: AMZN, AVGO, JPM, UNH or LIN reach maximums between 200 and 500, with intermediate volatility.
# - **Stable assets**: Energy, utilities and materials (XOM, CVX, NEE, VZ, DOW) show more contained prices and lower volatility.
# - **Volumes**: Wide variability between assets, with no relevant anomalies.
#
# ### Graphs Analysis
#
# #### Closing Price Comparison (2010–2026)
# The combined graph shows:
#
# - **Technology in strong ascent**, especially NVDA, MSFT and GOOG, with acceleration from 2016–2020.
# - **Impact of the 2020 crisis**, with widespread declines and faster recoveries in technology than in energy or finance.
# - **Sector divergence**: defensive sectors with flat trajectories versus growth sectors with markedly upward trends.
#
# #### Individual Graphs
# The asset-by-asset analysis shows:
#
# - **Generalized bullish trend** in most assets since 2010.
# - **Differentiated volatility** by sector: defensive assets more stable, cyclical assets more irregular.
# - **Post-COVID recovery** in all assets, although at different rates.
# - **Clear sector patterns**, such as late recovery in energy versus continuous growth in technology.
#
#
# ### Main Conclusions
#
# 1. **High quality dataset**: Perfect integrity, no additional cleaning needed.
# 2. **Heterogeneous behavior**: The 30 assets reveal very diverse patterns by sector, enabling regime analysis and sector rotation studies.
# 3. **Visible macroeconomic events**: 2020 crisis, subsequent recovery, digital transformation (technology) and inflation (energy) are clearly documented in prices.
# 4. **Dynamic universe necessary**: The late incorporation of META, ABBV and DOW requires a dynamic universe of stocks for backtesting analysis.
#
# ---
